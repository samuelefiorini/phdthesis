# %% [markdown]
# # Make plots
# This notebook loads the results coming from `../scripts/aging_model_challenge.py` and plot the results.

# %%
import cPickle as pkl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('seaborn-paper')
plt.rc('text', usetex=False)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 0. Load `pkl` files

# %%
def load_pkl(filename):
    """Load the input pkl file."""
    with open(filename,'rb') as f:
        dd = pkl.load(f)
    return dd

# %%
# Load model assessment result
ma = load_pkl('../scripts/fitted_ma_total.pkl')
times = load_pkl('../scripts/times_total.pkl')

# Load time elapsed
ma_poly = load_pkl('../scripts/fitted_ma_poly_total.pkl')
times_poly = load_pkl('../scripts/times_poly_total.pkl')

# %% [markdown]
# # 1. Evaluate scores

# %%
from sklearn import metrics

# %%
ma['linear_regression'].cv_results_['cv_results_']
# Out:
# [{'mean_fit_time': array([ 0.07614907]),
#   'mean_score_time': array([ 0.00065835]),
#   'mean_test_score': array([ 0.75687956]),
#   'mean_train_score': array([ 0.85437929]),
#   'params': [{}],
#   'rank_test_score': array([1], dtype=int32),
#   'split0_test_score': array([ 0.85700021]),
#   'split0_train_score': array([ 0.78929176]),
#   'split1_test_score': array([ 0.69568193]),
#   'split1_train_score': array([ 0.89206031]),
#   'split2_test_score': array([ 0.7145041]),
#   'split2_train_score': array([ 0.88178579]),
#   'std_fit_time': array([ 0.06053313]),
#   'std_score_time': array([ 0.00025655]),
#   'std_test_score': array([ 0.07241048]),
#   'std_train_score': array([ 0.04621458])},
#  {'mean_fit_time': array([ 0.19092663]),
#   'mean_score_time': array([ 0.00058166]),
#   'mean_test_score': array([ 0.72713138]),
#   'mean_train_score': array([ 0.86989682]),
#   'params': [{}],
#   'rank_test_score': array([1], dtype=int32),
# ...
